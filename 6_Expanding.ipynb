# %% [markdown]
# # Expanding
#
# - We will generate customer service emails that are tailored to each customer's review.
#
# ## Setup
#
# - Load the API key and relevant Python libaries.

# %%
from langchain_groq import ChatGroq
import langchain_core
import os
import warnings
warnings.filterwarnings('ignore')

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

groq_api_key = os.getenv('GROQ_API_KEY')

# %%
# model='llama-3.3-70b-versatile'

llm = ChatGroq(
    api_key=groq_api_key,
    model="llama-3.3-70b-versatile",
    temperature=0,
    max_tokens=None
)

# %%
def get_completion(prompt, model="llama-3.3-70b-versatile"):
    llm.model_name = model
    return llm.invoke(prompt).content

# %% [markdown]
# ## Customize the automated reply to a customer email

# %%
# given the sentiment from the lesson on "inferring",
# and the original customer message, customize the email
sentiment = "negative"

# review for a blender
review = f"""
So, they still had the 17 piece system on seasonal \
sale for around $49 in the month of November, about \
half off, but for some reason (call it price gouging) \
around the second week of December the prices all went \
up to about anywhere from between $70-$89 for the same \
system. And the 11 piece system went up around $10 or \
so in price also from the earlier sale price of $29. \
So it looks okay, but if you look at the base, the part \
where the blade locks into place doesn’t look as good \
as in previous editions from a few years ago, but I \
plan to be very gentle with it (example, I crush \
very hard items like beans, ice, rice, etc. in the \ 
blender first then pulverize them in the serving size \
I want in the blender then switch to the whipping \
blade for a finer flour, and use the cross cutting blade \
first when making smoothies, then use the flat blade \
if I need them finer/less pulpy). Special tip when making \
smoothies, finely cut and freeze the fruits and \
vegetables (if using spinach-lightly stew soften the \ 
spinach then freeze until ready for use-and if making \
sorbet, use a small to medium sized food processor) \ 
that you plan to use that way you can avoid adding so \
much ice if at all-when making your smoothie. \
After about a year, the motor was making a funny noise. \
I called customer service but the warranty expired \
already, so I had to buy another one. FYI: The overall \
quality has gone done in these types of products, so \
they are kind of counting on brand recognition and \
consumer loyalty to maintain sales. Got it in about \
two days.
"""

# %%
prompt = f"""
You are a customer service AI assistant.
Your task is to send an email reply to a valued customer.
Given the customer email delimited by ```, \
Generate a reply to thank the customer for their review.
If the sentiment is positive or neutral, thank them for \
their review.
If the sentiment is negative, apologize and suggest that \
they can reach out to customer service. 
Make sure to use specific details from the review.
Write in a concise and professional tone.
Sign the email as `AI customer agent`.
Customer review: ```{review}```
Review sentiment: {sentiment}
"""
response = get_completion(prompt)
print(response)
# Out:
# Subject: Re: Concerns with Recent Purchase and Price Increase
#
# Dear Valued Customer,
#
# Thank you for taking the time to share your review of our 17 piece system and 11 piece system. We apologize for the disappointment and frustration caused by the price increase, particularly during the holiday season. We understand that the sudden change from $49 to $70-$89 for the 17 piece system and the $10 price increase for the 11 piece system was unexpected and unwelcome.
#
# We also regret to hear that the quality of our product did not meet your expectations, specifically with regards to the base and blade locking mechanism. We appreciate the detailed feedback and the special tips you provided for using our products, such as freezing fruits and vegetables before making smoothies.
#
# Regarding the issue with the motor making a funny noise after a year, we apologize that our warranty had expired and you had to purchase another one. We understand that this experience has led you to feel that the overall quality of our products has declined.
#
# If you would like to discuss your concerns further or have any questions, please do not hesitate to reach out to our customer service team. We value your loyalty and would like to make things right.
#
# Thank you again for your review.
#
# Best regards,
# AI customer agent

# %% [markdown]
# ## Remind the model to use details from the customer's email

# %%
def get_completion(prompt, model="llama-3.3-70b-versatile", temperature=0):
    llm = ChatGroq(
        api_key=os.getenv("GROQ_API_KEY"),
        model=model,
        temperature=temperature,
        max_tokens=None
    )
    return llm.invoke(prompt).content

# %%
prompt = f"""
You are a customer service AI assistant.
Your task is to send an email reply to a valued customer.
Given the customer email delimited by ```, \
Generate a reply to thank the customer for their review.
If the sentiment is positive or neutral, thank them for \
their review.
If the sentiment is negative, apologize and suggest that \
they can reach out to customer service. 
Make sure to use specific details from the review.
Write in a concise and professional tone.
Sign the email as `AI customer agent`.
Customer review: ```{review}```
Review sentiment: {sentiment}
"""
response = get_completion(prompt, temperature=0.7)
print(response)
# Out:
# Subject: Concern with Recent Purchase and Price Increase
#
# Dear Valued Customer,
#
# Thank you for taking the time to share your review of our 17 piece system and 11 piece system. We apologize for the disappointment and frustration caused by the price increase, particularly during the holiday season. You mentioned that the price jumped from $49 to $70-$89 for the 17 piece system, and the 11 piece system also saw a price increase of around $10. We understand that this sudden change may have affected your perception of our product's value.
#
# We also appreciate your detailed feedback on the product's design and quality. You noted that the base of the system, where the blade locks into place, does not seem as sturdy as in previous editions. We will take this into consideration for future product improvements.
#
# Regarding the issue with the motor making a funny noise after about a year, we regret that the warranty had expired, and you had to purchase a new one. We understand that this experience may have fallen short of your expectations.
#
# We want to assure you that we value your loyalty and appreciate your tips on using our products, such as freezing fruits and vegetables before making smoothies. Your feedback is crucial in helping us to identify areas for improvement.
#
# If you would like to discuss your concerns further or need assistance with any of our products, please do not hesitate to reach out to our customer service team. We are here to help.
#
# Thank you again for your review, and we hope to have the opportunity to serve you better in the future.
#
# Best regards,
# AI customer agent
